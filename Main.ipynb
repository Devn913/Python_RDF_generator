# %%
# !pip install rdflib
# !pip install pandas

# %%
from rdflib import URIRef, BNode, Literal, Namespace, Graph
from rdflib.namespace import FOAF,  DCTERMS, XSD, RDF, SDO
import pandas as pd

# %%
df = pd.read_csv('prod.csv', index_col=False)
df
# Out:
#     Product id     Product Name  RAM (in GB)  SDD (in GB)  Price (in INR)  \
# 0            1      Acer Aspire            4          256           31000
# 1            2          Macbook            8          128           87000
# 2            3  Lenevo notebook            8          512           47000
# 3            4    Acer Notebook           16          256           35000
# 4            5       Acer NItro           16          256           87000
# 5            6               HP            8          512           40000
# 6            7    HP Chromebook            8           64           21000
# 7            8    Asus Vivobook            4          256           27999
# 8            9  Asus Chromebook            8           64           21000
# 9           10            Dell             4          512           59000
# 10          11          Macbook           16          512          111700
#
#     Processor  ScreenSize(in inch)
# 0          i5                 15.5
# ...

# %%
g = Graph()
ex = Namespace('https://www.example.org/')
id = ex['id']
productID = ex['hasProductID']
name  = ex['name']
ram  = ex['hasRAM']
ssd = ex['hasSSD']
price = ex['hasPrice']
processor = ex['hasProcessor']
screen = ex['hasScreenSize']

# %%
df['Product id']

# %%
import rdflib.tools.csv2rdf as rdfc
rdfc.CSV2RDF()
